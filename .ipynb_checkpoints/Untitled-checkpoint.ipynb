# %%
# Importing Libs

import numpy as np # Linear Algebra
import pandas as pd # Data Manipulation
import seaborn as sns # Data Viz
import matplotlib.pyplot as plt # Data Viz
from sklearn.preprocessing import OneHotEncoder,LabelEncoder # Perform OneHotEnconding
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import classification_report, roc_auc_score,precision_score,recall_score,r2_score # Evaluating the Model
#warnings
import warnings
warnings.filterwarnings("ignore")

# %%
df_test=pd.read_csv('df_merged_final_weathermodified_test.csv',index_col=[0])

# %%
df_test
# Out:
#        Unnamed: 0     fl_date mkt_unique_carrier branded_code_share  \
# 0              14  2020-01-01                 WN                 WN
# 1              15  2020-01-01                 WN                 WN
# 2              16  2020-01-01                 WN                 WN
# 3              17  2020-01-01                 WN                 WN
# 4              21  2020-01-01                 WN                 WN
# ...           ...         ...                ...                ...
# 17765       15971  2020-01-01                 AS                 AS
# 17766       15956  2020-01-01                 AS                 AS
# 17767       15963  2020-01-01                 AS                 AS
# 17768       15958  2020-01-01                 AS                 AS
# 17769       18856  2020-01-01                 UA                 UA
#
#       mkt_carrier  mkt_carrier_fl_num op_unique_carrier tail_num  \
# 0              WN                3719                WN   N941WN
# ...

# %%
df=pd.read_csv('df_testing_test.csv',index_col=[0])

# %%
df_test
# Out:
#        Unnamed: 0     fl_date mkt_unique_carrier branded_code_share  \
# 0              14  2020-01-01                 WN                 WN
# 1              15  2020-01-01                 WN                 WN
# 2              16  2020-01-01                 WN                 WN
# 3              17  2020-01-01                 WN                 WN
# 4              21  2020-01-01                 WN                 WN
# ...           ...         ...                ...                ...
# 17765       15971  2020-01-01                 AS                 AS
# 17766       15956  2020-01-01                 AS                 AS
# 17767       15963  2020-01-01                 AS                 AS
# 17768       15958  2020-01-01                 AS                 AS
# 17769       18856  2020-01-01                 UA                 UA
#
#       mkt_carrier  mkt_carrier_fl_num op_unique_carrier tail_num  \
# 0              WN                3719                WN   N941WN
# ...

# %%
df_tmp=pd.read_csv('tmp.csv',index_col=[0])

# %%
df_tmp
# Out:
#            fl_date mkt_unique_carrier branded_code_share mkt_carrier  \
# 0       2018-01-01                 DL       DL_CODESHARE          DL
# 1       2019-01-01                 DL       DL_CODESHARE          DL
# 2       2019-01-13                 DL       DL_CODESHARE          DL
# 3       2019-01-14                 DL       DL_CODESHARE          DL
# 4       2019-01-15                 DL       DL_CODESHARE          DL
# ...            ...                ...                ...         ...
# 704855  2019-01-31                 G4                 G4          G4
# 704856  2019-01-31                 UA                 UA          UA
# 704857  2019-01-31                 G4                 G4          G4
# 704858  2019-01-31                 G4                 G4          G4
# 704859  2019-01-31                 G4                 G4          G4
#
#         mkt_carrier_fl_num op_unique_carrier tail_num  op_carrier_fl_num  \
# ...

# %%
dep=df_tmp[['origin','dest','op_unique_carrier','crs_dep_timeblk', 'route_day_timeblk_airline_avg_dep']]
arr=df_tmp[['origin','dest','op_unique_carrier','crs_arr_timeblk', 'route_day_timeblk_airline_avg_arr']]

# %%
df
# Out:
#       op_unique_carrier  origin_airport_id origin  dest_airport_id dest  \
# 0                    WN              13931    ORF            10821  BWI
# 1                    WN              13931    ORF            10821  BWI
# 2                    WN              13931    ORF            10821  BWI
# 3                    WN              13931    ORF            10821  BWI
# 4                    WN              14027    PBI            10821  BWI
# ...                 ...                ...    ...              ...  ...
# 17765                AS              12523    JNU            14828  SIT
# 17766                AS              12523    JNU            14256  PSG
# 17767                AS              15841    WRG            14256  PSG
# 17768                AS              14256    PSG            15841  WRG
# 17769                UA              12016    GUM            14955  SPN
#
#        crs_dep_time  crs_arr_time dup  crs_elapsed_time  distance  \
# ...

# %%
dep
# Out:
#        origin dest op_unique_carrier crs_dep_timeblk  \
# 0         TVC  DTW                9E          RedEye
# 1         TVC  DTW                9E          RedEye
# 2         TVC  DTW                9E         Morning
# 3         TVC  DTW                9E         Morning
# 4         TVC  DTW                9E         Morning
# ...       ...  ...               ...             ...
# 704855    SFB  PIT                G4         Morning
# 704856    IAH  SAV                UA         Evening
# 704857    ALB  SFB                G4       Afternoon
# 704858    BLV  SFB                G4       Afternoon
# 704859    SFB  BLV                G4       Afternoon
#
#         route_day_timeblk_airline_avg_dep
# 0                                  405.00
# 1                                  405.00
# 2                                   35.25
# 3                                   35.25
# 4                                   35.25
# ...                                   ...
# ...

# %%
df_test.merge(dep, left_on=['origin','dest','op_unique_carrier','crs_dep_timeblk'],right_on=['origin','dest','op_unique_carrier','crs_dep_timeblk']).drop_duplicates(keep='first')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [109], in <cell line: 1>()
# ----> 1 df_test.merge(dep, left_on=['origin','dest','op_unique_carrier','crs_dep_timeblk'],right_on=['origin','dest','op_unique_carrier','crs_dep_timeblk']).drop_duplicates(keep='first')
#
# File ~/opt/anaconda3/envs/ml_env/lib/python3.9/site-packages/pandas/core/frame.py:9345, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9326 @Substitution("")
#    9327 @Appender(_merge_doc, indents=2)
#    9328 def merge(
#    (...)
#    9341     validate: str | None = None,
#    9342 ) -> DataFrame:
#    9343     from pandas.core.reshape.merge import merge
# -> 9345     return merge(
#    9346         self,
#    9347         right,
#    9348         how=how,
#    9349         on=on,
#    9350         left_on=left_on,
# ...

# %%
tmppp=df_test.merge(dep, left_on=['origin','dest','op_unique_carrier','crs_dep_timeblk'],right_on=['origin','dest','op_unique_carrier','crs_dep_timeblk']).drop_duplicates(keep='first')

# %%
df.drop('dup',axis=1,inplace=True)

# %%
df.to_csv('df_flights_test_data.csv')

# %%
import pickle
# pickle_in=open("df_flights_test_data.pickle","wb")
# pickle.dump(df,pickle_in)
# pickle_in.close()

# %%
pickle_out=open('df_flights_test_data.pickle',"rb")
df_testing=pickle.load(pickle_out)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

# %%
df_testing=df.copy()

# %%
X_1=pd.get_dummies(df_testing_1)

# %%
X_2=pd.get_dummies(df_testing_2)

# %%
X_3=pd.get_dummies(df_testing_3)

# %%
rfr = RandomForestRegressor(max_depth=15,max_features='auto',min_samples_leaf= 5,min_samples_split= 10,n_estimators= 200)

# %%
y_predict_1=rfr.predict(X_1)

# %%
y_predict_2=rfr.predict(X_2)
